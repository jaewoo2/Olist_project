# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
reviews = pd.read_csv('../data/processed_v2/olist_order_reviews_dataset.csv')

# %%
reviews.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 98673 entries, 0 to 98672
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                98673 non-null  str
#  1   order_id                 98673 non-null  str
#  2   review_score             98673 non-null  int64
#  3   review_comment_title     11552 non-null  str
#  4   review_comment_message   40774 non-null  str
#  5   review_creation_date     98673 non-null  str
#  6   review_answer_timestamp  98673 non-null  str
# dtypes: int64(1), str(6)
# memory usage: 17.7 MB

# %%
master_orders = pd.read_csv('../data/master_begin2017/master_orders_begin2017.csv')

# %%
master_begin2017.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 94819 entries, 0 to 94818
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       94819 non-null  str
#  1   customer_id                    94819 non-null  str
#  2   order_status                   94819 non-null  str
#  3   order_purchase_timestamp       94819 non-null  str
#  4   order_approved_at              94819 non-null  str
#  5   order_delivered_carrier_date   94819 non-null  str
#  6   order_delivered_customer_date  94819 non-null  str
#  7   order_estimated_delivery_date  94819 non-null  str
#  8   total_delivery_time            94819 non-null  int64
#  9   seller_prep_time               94819 non-null  int64
#  10  pure_shipping_time             94819 non-null  int64
#  11  delivery_accuracy              94819 non-null  int64
#  12  estimated_wait_time            94819 non-null  int64
# ...

# %%
origin_orders = pd.read_csv('../data/raw/olist_orders_dataset.csv')

# %%
origin_orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  str
#  4   order_approved_at              99281 non-null  str
#  5   order_delivered_carrier_date   97658 non-null  str
#  6   order_delivered_customer_date  96476 non-null  str
#  7   order_estimated_delivery_date  99441 non-null  str
# dtypes: str(8)
# memory usage: 21.9 MB

# %%
origin_orders['order_status'].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
master_sellers = pd.read_csv('../data/master_begin2017/master_sellers_begin2017.csv')

# %%
master_sellers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   seller_id          2930 non-null   str
#  1   total_orders       2930 non-null   int64
#  2   total_items        2930 non-null   int64
#  3   total_revenue      2930 non-null   float64
#  4   total_freight      2930 non-null   float64
#  5   avg_review_score   2930 non-null   float64
#  6   review_count       2930 non-null   int64
#  7   five_star_count    2930 non-null   int64
#  8   one_star_count     2930 non-null   int64
#  9   avg_delivery_days  2930 non-null   float64
#  10  delay_count        2930 non-null   float64
#  11  first_order_date   2930 non-null   str
#  12  last_order_date    2930 non-null   str
#  13  total_gmv          2930 non-null   float64
#  14  five_star_rate     2930 non-null   float64
#  15  one_star_rate      2930 non-null   float64
# ...

# %%
geo = pd.read_csv('../data/processed_v2/olist_geolocation_dataset.csv')
geo.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
geo.groupby('geolocation_state')[['geolocation_lat','geolocation_lng']].mean()
# Out:
#                    geolocation_lat  geolocation_lng
# geolocation_state
# AC                       -9.702555       -68.451852
# AL                       -9.599729       -36.052017
# AM                       -3.349336       -60.537430
# AP                        0.086025       -51.234304
# BA                      -13.049361       -39.560649
# CE                       -4.363151       -39.004140
# DF                      -15.810885       -47.969630
# ES                      -20.105145       -40.503183
# GO                      -16.577645       -49.334195
# MA                       -3.798997       -44.818627
# MG                      -19.864647       -44.421615
# MS                      -20.765006       -54.532140
# MT                      -14.156482       -55.708956
# PA                       -2.631213       -49.485862
# PB                       -7.088298       -35.821678
# PE                       -8.179098       -35.758866
# PI                       -5.754989       -42.509541
# ...
